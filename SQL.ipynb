# %% [markdown]
# # Sql w Pytonie
# * są różne metody dostania się do danych:
#         - bezpośredni sterownik np. PostgreSql
#         - SqlAlchemy
#         - Pandas

# %%
import psycopg2

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/postgres')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-cd60cd4a61c5> in <module>()
# ----> 1 engine.table_names()
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2134         """
#    2135
# -> 2136         with self._optional_conn_ctx_manager(connection) as conn:
#    2137             if not schema:
#    2138                 schema = self.dialect.default_schema_name
#
# /Users/kamil/.pyenv/versions/3.4.6/lib/python3.4/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    1930     def _optional_conn_ctx_manager(self, connection=None):
#    1931         if connection is None:
# -> 1932             with self.contextual_connect() as conn:
#    1933                 yield conn
#    1934         else:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in connect(self)
#     398         """
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#     402         try:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# /Users/kamil/code/datascience/venv/lib/python3.4/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#  (Background on this error at: http://sqlalche.me/e/e3q8)
